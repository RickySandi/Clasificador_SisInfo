# %%
#Habilitar intellisense
# %config IPCompleter.greedy=True

# %%
import pandas as pd
import numpy as np
import nltk
from xgboost.sklearn import XGBClassifier
import string
from nltk.tokenize import sent_tokenize
from bs4 import BeautifulSoup
import re
import pickle
import os
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score
from sklearn.ensemble import RandomForestClassifier

# %%
data = pd.read_csv('imdb_dataset.csv',encoding="ISO-8859-1")
data.head()
# Out:
#                                               Review Label
# 0  Once again Mr. Costner has dragged out a movie...   neg
# 1  This is an example of why the majority of acti...   neg
# 2  First of all I hate those moronic rappers, who...   neg
# 3  Not even the Beatles could write songs everyon...   neg
# 4  Brass pictures (movies is not a fitting word f...   neg

# %%
# print(data.shape) # (50000, 1)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Review  50000 non-null  object
#  1   Label   50000 non-null  object
# dtypes: object(2)
# memory usage: 781.4+ KB

# %%
#data_prueba=data.sample(frac=0.2)


#Guardando data -> 20% = 10.000
# # #Crear DataFrame de 10.000 
# df = pd.DataFrame(poblacion) 
# muestra = df.sample(n = 10000)
# muestra.head() #Es aleatorio, cada vez hay nuevos valores -> Resultados deberian ser parecidos 

#Exportar DataFrame
#data_prueba.to_csv ('imdb_dataset_prueba.csv')

# %%
data = pd.read_csv('imdb_dataset_prueba.csv',encoding="ISO-8859-1")
data.head()
# Out:
#    Unnamed: 0                                             Review Label
# 0       32116  If you are planning to rent or buy this movie ...   neg
# 1       13493  Quite simply, Goldeneye is the single greatest...   pos
# 2        1067  Well, here we have a zombie movie that perhaps...   neg
# 3       36150  I first heard about White Noise when I saw the...   neg
# 4       39376  Tony Arzenta, a Sicilian hit-man or profession...   pos

# %%
# print(data.shape) # (50000, 1)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  10000 non-null  int64
#  1   Review      10000 non-null  object
#  2   Label       10000 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 234.5+ KB

# %%
data = data.loc[:, ~data.columns.str.contains('^Unnamed')] #Limpiar la columna Unnamed

# %%
#data.info()
data.head()
# Out:
#                                               Review Label
# 0  If you are planning to rent or buy this movie ...   neg
# 1  Quite simply, Goldeneye is the single greatest...   pos
# 2  Well, here we have a zombie movie that perhaps...   neg
# 3  I first heard about White Noise when I saw the...   neg
# 4  Tony Arzenta, a Sicilian hit-man or profession...   pos

# %%
palabrasParada = set( nltk.corpus.stopwords.words('english') + list(string.punctuation)+["...","..","hr"])
#palabrasParada

# %%
def sinhtml(conHTML):
    limpiar_html = re.compile('<.*?>|&([a-z0-9]+|#[0-9]{1,6}|#x[0-9a-f]{1,6});')
    sin_html = re.sub(limpiar_html, '', conHTML)
    return sin_html

def quitar_html(palabras):
    array = []
    for palabra in  palabras:
        sinHtml = sinhtml(palabra)
        array.append(sinHtml)
    return array

def quitarComillas(palabras):
    array = []
    for palabra in  palabras:
        palabra = palabra.strip("'")
        palabra = palabra.strip("`")
        array.append(palabra)
    return array

def Tokenizar(texto):
    texto=texto.lower()
    palabras = nltk.word_tokenize(texto)#separa las palabras
    return [palabra for palabra in palabras if palabra not in palabrasParada]#quita stopwords
def listToString(lista):  
    str1 = " " 
    return (str1.join(lista))

# %%
listaDeComentarios=[]
for index, row in data.iterrows():
    
    tokenizado=Tokenizar(row['Review'])
    
    sinHTML=quitar_html(tokenizado)
    
    sinComillas=quitarComillas(sinHTML)
    
    lista=listToString(sinComillas)
    
    listaDeComentarios.append(lista)
    
listaDeComentarios[0]
# Out:
# "planning rent buy movie n't s worst thing ever seen would comment 10 years since saw blanked mind save time money well stay far far away"

# %%
listaDeComentarios = np.array(listaDeComentarios) #Convirtiendo la lista de cometario a np.array 
print(type(listaDeComentarios))
# Out:
# <class 'numpy.ndarray'>

# %%
listaDeComentarios.shape
# Out:
# (10000,)

# %%
def get_problem_vocabulary(normalized_corpus): #Devuelve lista ordenada con tokens normalizados
    all_tokens = [] 
    for document in normalized_corpus:
        all_tokens.extend(document.split())  
    all_tokens_sorted = sorted(set(all_tokens))
    
    token_and_position = {}
    for i, token in enumerate(all_tokens_sorted):
        token_and_position[token] = i
    
    return token_and_position



problem_vocabulary = get_problem_vocabulary(listaDeComentarios)
print("Tamaño del lista: ",len(problem_vocabulary))
# Out:
# Tamaño del lista:  68795

# %%
#problem_vocabulary #Lista  con el vocabulario del problema
# Out:
# {',01.': 0,
#  '-': 1,
#  "-'stupidity": 2,
#  '--': 3,
#  '-1': 4,
#  '-1/10': 5,
#  '-10': 6,
#  '-10/10': 7,
#  '-13': 8,
#  '-2': 9,
#  '-3': 10,
#  '-42.': 11,
#  '-5': 12,
#  '-50': 13,
#  '-8/10': 14,
#  '-=contains': 15,
#  '-a': 16,
#  '-a-': 17,
#  '-again-': 18,
#  '-alexander': 19,
#  '-alfred': 20,
#  '-all': 21,
#  '-almost': 22,
#  '-although': 23,
#  '-an': 24,
#  '-and': 25,
#  '-anonymous': 26,
#  '-ap3-': 27,
#  '-apparently': 28,
#  '-army': 29,
#  '-as': 30,
#  '-at': 31,
#  '-atlantis': 32,
#  '-atlantis-': 33,
#  '-audley': 34,
#  '-band': 35,
#  '-best': 36,
#  '-big': 37,
#  '-black': 38,
#  '-budget': 39,
#  '-bush': 40,
#  '-but': 41,
#  '-capital': 42,
#  '-carmen': 43,
#  '-casting-': 44,
#  '-cgi-': 45,
#  '-characters-': 46,
#  '-chris': 47,
#  '-contest': 48,
#  '-d': 49,
#  '-dario': 50,
#  '-darth': 51,
#  '-dear': 52,
#  '-do': 53,
#  '-during': 54,
#  '-ee': 55,
#  '-end': 56,
#  '-especially': 57,
#  '-esquire': 58,
#  '-even': 59,
#  '-everything': 60,
#  '-exactly': 61,
#  '-fan': 62,
#  '-featurette': 63,
#  '-feeling': 64,
#  '-finally': 65,
#  '-for': 66,
#  '-force': 67,
#  '-from': 68,
#  '-full': 69,
#  '-genre': 70,
#  '-girl': 71,
#  '-god': 72,
#  '-good-': 73,
#  '-haired': 74,
#  '-happy': 75,
#  '-have': 76,
#  '-he': 77,
#  '-her': 78,
#  '-high': 79,
#  '-hilarious': 80,
#  '-his': 81,
#  '-ho': 82,
#  '-home': 83,
#  '-i': 84,
#  '-if': 85,
#  '-imdb': 86,
#  '-implausable-': 87,
#  '-in': 88,
#  '-influenced': 89,
#  '-interesting': 90,
#  '-it': 91,
#  "-it's-": 92,
#  '-jorg': 93,
#  '-joy': 94,
#  '-just': 95,
#  '-kelly': 96,
#  '-kind': 97,
#  '-kish': 98,
#  '-la': 99,
#  '-let': 100,
#  '-light': 101,
#  '-lights': 102,
#  '-like': 103,
#  '-liked-': 104,
#  '-lyndsay': 105,
#  '-magictrain': 106,
#  '-main': 107,
#  '-maybe': 108,
#  '-me': 109,
#  '-merimee': 110,
#  '-might': 111,
#  '-modernism-': 112,
#  '-movie': 113,
#  '-movies': 114,
#  '-music-': 115,
#  '-natured': 116,
#  '-neither': 117,
#  '-no': 118,
#  '-not': 119,
#  '-note': 120,
#  '-of': 121,
#  '-offs': 122,
#  '-oh': 123,
#  '-ok': 124,
#  '-okay': 125,
#  '-one': 126,
#  '-or': 127,
#  '-other': 128,
#  '-overall': 129,
#  '-p': 130,
#  '-particularly': 131,
#  '-party': 132,
#  '-people': 133,
#  '-platforms': 134,
#  '-plus': 135,
#  '-poor': 136,
#  '-power-walking': 137,
#  '-print': 138,
#  '-r': 139,
#  '-rather': 140,
#  '-real': 141,
#  '-realized': 142,
#  '-s': 143,
#  '-s.': 144,
#  '-screened': 145,
#  '-see': 146,
#  '-seemingly-': 147,
#  '-semantics': 148,
#  '-shame': 149,
#  '-she': 150,
#  '-shoe': 151,
#  '-short': 152,
#  '-skinned': 153,
#  '-so': 154,
#  '-spoiler-': 155,
#  '-spoilers': 156,
#  '-spoiles-': 157,
#  '-stamos': 158,
#  '-stereotypical': 159,
#  '-stories': 160,
#  '-story': 161,
#  '-style': 162,
#  '-stylized': 163,
#  '-sucky': 164,
#  '-tara': 165,
#  '-that': 166,
#  '-the': 167,
#  '-their': 168,
#  '-thenã\x82': 169,
#  '-there': 170,
#  '-they': 171,
#  '-this': 172,
#  '-time': 173,
#  '-to-be-missed': 174,
#  '-two': 175,
#  '-type': 176,
#  '-uel': 177,
#  '-up': 178,
#  '-ups': 179,
#  '-valley': 180,
#  '-vampire': 181,
#  '-versy': 182,
#  '-visuals-': 183,
#  '-vote': 184,
#  '-wadget-': 185,
#  '-wait': 186,
#  '-wannabe': 187,
#  '-warning': 188,
#  '-wasted': 189,
#  '-we': 190,
#  '-when': 191,
#  '-which': 192,
#  '-who': 193,
#  '-widget-': 194,
#  '-wiley': 195,
#  '-will': 196,
#  '-woman': 197,
#  '-x-': 198,
#  '-you': 199,
#  '-z': 200,
#  '-zafoid': 201,
#  '-zaphoid': 202,
#  '-|': 203,
#  '.': 204,
#  '....': 205,
#  '.....': 206,
#  '......': 207,
#  '.......': 208,
#  '........': 209,
#  '.........': 210,
#  '..........': 211,
#  '...........': 212,
#  '............': 213,
#  '..............': 214,
#  '...............': 215,
#  '................': 216,
#  '...................': 217,
#  '.....................': 218,
#  '..............................': 219,
#  '................................': 220,
#  '..........................................': 221,
#  '.................................................': 222,
#  '.01': 223,
#  '.1': 224,
#  '.22': 225,
#  '.30': 226,
#  '.357': 227,
#  '.38': 228,
#  '.38s': 229,
#  '.4': 230,
#  '.44': 231,
#  '.45': 232,
#  '.49': 233,
#  '.5': 234,
#  '.50': 235,
#  '.58': 236,
#  '.99': 237,
#  '.aamir': 238,
#  '.akasha': 239,
#  '.alas': 240,
#  '.all': 241,
#  '.also': 242,
#  '.altough': 243,
#  '.and': 244,
#  '.antimilitarism': 245,
#  '.antoine': 246,
#  '.as': 247,
#  '.ask': 248,
#  '.basicly': 249,
#  '.being': 250,
#  '.brodie': 251,
#  '.but': 252,
#  '.cartman': 253,
#  '.check': 254,
#  '.children': 255,
#  '.conrack': 256,
#  '.cripple': 257,
#  '.director': 258,
#  '.do': 259,
#  '.etc': 260,
#  '.even': 261,
#  '.everything': 262,
#  '.excellent': 263,
#  '.for': 264,
#  '.give': 265,
#  '.he': 266,
#  '.henri': 267,
#  '.here': 268,
#  '.however': 269,
#  '.i': 270,
#  '.in': 271,
#  '.initially': 272,
#  '.it': 273,
#  '.j': 274,
#  '.just': 275,
#  '.lahaie': 276,
#  '.lets': 277,
#  '.listening': 278,
#  '.loud': 279,
#  '.man': 280,
#  '.maybe': 281,
#  '.meanwhile': 282,
#  '.michael': 283,
#  '.needless': 284,
#  '.now': 285,
#  '.oh': 286,
#  '.on': 287,
#  '.only': 288,
#  '.our': 289,
#  '.paul': 290,
#  '.pdf': 291,
#  '.personally': 292,
#  '.probably': 293,
#  '.raft': 294,
#  '.rent': 295,
#  '.see': 296,
#  '.set': 297,
#  '.she': 298,
#  '.stewart': 299,
#  '.stumbled': 300,
#  '.thank': 301,
#  '.the': 302,
#  '.then': 303,
#  '.there': 304,
#  '.they': 305,
#  '.this': 306,
#  '.to': 307,
#  '.unfortunately': 308,
#  '.we': 309,
#  '.what': 310,
#  '.who': 311,
#  '.why': 312,
#  '.with': 313,
#  '.wrong': 314,
#  '.you': 315,
#  '//': 316,
#  '//barbra-archives.com/films/clear_day_streisand_2.html': 317,
#  '//black': 318,
#  '//blog.ifeng.com/article/2737487.html': 319,
#  '//blog.myspace.com/locoformovies': 320,
#  '//i': 321,
#  '//mcmusicnotes.blogspot.com': 322,
#  '//moviemusereviews.blogspot.com': 323,
#  '//rateyourmusic.com/~fedor8': 324,
#  '//thevillagevideot.blogspot.com/': 325,
#  '//us.imdb.com/title/tt0087072': 326,
#  '//without-terebi.blogspot.com/2009/08/thirst-aka-bakjwi.html': 327,
#  '//www.biz-community.com/article/196/97/5223.html': 328,
#  '//www.cinemablend.com/feature.php': 329,
#  '//www.cinemablend.com/forum/showthread.php': 330,
#  '//www.comingsoon.net/films.php': 331,
#  '//www.gutenberg.org/ebooks/18137': 332,
#  '//www.imdb.com/title/tt0077713/': 333,
#  '//www.imdb.com/title/tt0363163/': 334,
#  '//www.screenonline.org.uk/tv/id/527213/index.html': 335,
#  '//www.theindependent.com/twisters/': 336,
#  '//www.thepetitionsite.com': 337,
#  '//www.youtube.com/watch': 338,
#  '//www.zonadvd.com': 339,
#  '//zuucka.deviantart.com/art/uwe-boll-is-a-douchebag-70369862': 340,
#  '/1/we-want-an-80s-child-cartoon-kids-show-channel': 341,
#  '/10': 342,
#  '/5': 343,
#  '/critters': 344,
#  '/editing': 345,
#  '/hjm': 346,
#  '/is/': 347,
#  '/lead': 348,
#  '/on': 349,
#  '/one': 350,
#  '/or': 351,
#  '/producer/playwright': 352,
#  '/rip-offs': 353,
#  '/the': 354,
#  '/uk': 355,
#  '0': 356,
#  '0-30': 357,
#  '0.': 358,
#  '0.02': 359,
#  '0.2-0.5': 360,
#  '0.5': 361,
#  '0.5/10': 362,
#  '0.7-kiloton': 363,
#  '0/0': 364,
#  '0/10': 365,
#  '0/4': 366,
#  '0/5': 367,
#  '00': 368,
#  '007': 369,
#  '0080': 370,
#  '00s': 371,
#  '029': 372,
#  '03': 373,
#  '04/08/2007': 374,
#  '05': 375,
#  '06': 376,
#  '06.': 377,
#  '06.and': 378,
#  '07.': 379,
#  '08': 380,
#  '087': 381,
#  '08th': 382,
#  '09': 383,
#  '09-15-05': 384,
#  '09/08/2009': 385,
#  '1': 386,
#  '1+': 387,
#  '1+2': 388,
#  '1,000': 389,
#  '1,000,000': 390,
#  '1,000-5,000': 391,
#  '1,000.00': 392,
#  '1,2,3': 393,
#  '1,238.67': 394,
#  '1,5': 395,
#  '1,500': 396,
#  '1-': 397,
#  '1-1/2': 398,
#  '1-10': 399,
#  '1-2': 400,
#  '1-3': 401,
#  '1-7.': 402,
#  '1-800-makeover': 403,
#  '1-day': 404,
#  '1-dimensional': 405,
#  '1-in-1000': 406,
#  '1-store': 407,
#  '1.': 408,
#  '1.00': 409,
#  '1.1': 410,
#  '1.1/10': 411,
#  '1.25': 412,
#  '1.3/10': 413,
#  '1.30': 414,
#  '1.33:1': 415,
#  '1.37:1': 416,
#  '1.4': 417,
#  '1.44': 418,
#  '1.5': 419,
#  '1.5/10': 420,
#  '1.5/5': 421,
#  '1.50': 422,
#  '1.5hrs': 423,
#  '1.7': 424,
#  '1.78:1': 425,
#  '1.8': 426,
#  '1.85:1': 427,
#  '1.9/10': 428,
#  '1.985': 429,
#  '1.99': 430,
#  '1.it': 431,
#  '1.monsoon': 432,
#  '1.the': 433,
#  '1/': 434,
#  '1/1/21': 435,
#  '1/10': 436,
#  '1/10.': 437,
#  '1/100': 438,
#  '1/100th': 439,
#  '1/16th': 440,
#  '1/2': 441,
#  '1/2-hour': 442,
#  '1/2/': 443,
#  '1/2/3': 444,
#  '1/2007': 445,
#  '1/2h': 446,
#  '1/3': 447,
#  '1/336th': 448,
#  '1/3s': 449,
#  '1/4': 450,
#  '1/5': 451,
#  '1/6': 452,
#  '1/jesus': 453,
#  '10': 454,
#  '10+': 455,
#  '10,000': 456,
#  '10-11': 457,
#  '10-12': 458,
#  '10-15': 459,
#  '10-20': 460,
#  '10-20000': 461,
#  '10-25': 462,
#  '10-3-07': 463,
#  '10-4': 464,
#  '10-cents-a-dance': 465,
#  '10-check': 466,
#  '10-day': 467,
#  '10-minute': 468,
#  '10-of-10': 469,
#  '10-page': 470,
#  '10-speed': 471,
#  '10-year': 472,
#  '10-year-old': 473,
#  '10-yr-old': 474,
#  '10.': 475,
#  '10.0': 476,
#  '10.00': 477,
#  '10.000': 478,
#  '10.5': 479,
#  '10.as': 480,
#  '10.just': 481,
#  '10/10': 482,
#  '10/10.': 483,
#  '10/11': 484,
#  '10/29/55': 485,
#  '10/7/2000': 486,
#  '100': 487,
#  '100+': 488,
#  '100,000': 489,
#  '100,000,000': 490,
#  '100,000.00': 491,
#  '100-200': 492,
#  '100-million-plus': 493,
#  '100-minute': 494,
#  '100-plus': 495,
#  '100.': 496,
#  '100.000': 497,
#  '1000': 498,
#  '1000-2000': 499,
#  '1000.': 500,
#  '10000': 501,
#  '1000000': 502,
#  '10000000000000/10000000000000': 503,
#  '1004': 504,
#  '100k': 505,
#  '100th': 506,
#  '100ã\x82â°f': 507,
#  '101': 508,
#  '101.': 509,
#  '102': 510,
#  '102.': 511,
#  '103': 512,
#  '104': 513,
#  '1040': 514,
#  '1040a': 515,
#  '105': 516,
#  '1050': 517,
#  '106': 518,
#  '107': 519,
#  '108': 520,
#  '109': 521,
#  '10:30pm': 522,
#  '10\\10.i': 523,
#  '10mil': 524,
#  '10s': 525,
#  '10star': 526,
#  '10th': 527,
#  '11': 528,
#  '11-29-02.': 529,
#  '11-year': 530,
#  '11-year-old': 531,
#  '11.': 532,
#  '11.50': 533,
#  '11/10': 534,
#  '110': 535,
#  '110-minute': 536,
#  '1100': 537,
#  '11001001': 538,
#  '111': 539,
#  '112': 540,
#  '113': 541,
#  '1138': 542,
#  '116': 543,
#  '117': 544,
#  '11706': 545,
#  '119': 546,
#  '11:00': 547,
#  '11:11': 548,
#  '11:15am': 549,
#  '11th': 550,
#  '11yr': 551,
#  '12': 552,
#  '12,000': 553,
#  '12-13': 554,
#  '12-14': 555,
#  '12-16': 556,
#  '12-1am': 557,
#  '12-hour': 558,
#  '12-year': 559,
#  '12-year-old': 560,
#  '12.': 561,
#  '12.00': 562,
#  '12/1/34': 563,
#  '12/17/01': 564,
#  '12/31/05': 565,
#  '120': 566,
#  '1200': 567,
#  '1201': 568,
#  '1202': 569,
#  '123': 570,
#  '123,000,000': 571,
#  '1242': 572,
#  '125': 573,
#  '12:00': 574,
#  '12:01': 575,
#  '12:45-1:19': 576,
#  '12:45am': 577,
#  '12a': 578,
#  '12m': 579,
#  '12th': 580,
#  '13': 581,
#  '13-inch': 582,
#  '13-year': 583,
#  '13-year-old': 584,
#  '13-year-olds': 585,
#  '13.': 586,
#  '13.00': 587,
#  '130': 588,
#  '130,000': 589,
#  '130.000': 590,
#  '1300': 591,
#  '1300s': 592,
#  '134': 593,
#  '134-minute': 594,
#  '135': 595,
#  '138': 596,
#  '13:3-5': 597,
#  '13k': 598,
#  '13th': 599,
#  '14': 600,
#  '14-going-on-9': 601,
#  '14-movie': 602,
#  '14-year': 603,
#  '14-year-old': 604,
#  '14-year-old-girl': 605,
#  '14.': 606,
#  '14.00': 607,
#  '14/15': 608,
#  '140': 609,
#  '140-minute': 610,
#  '1408': 611,
#  '1408.': 612,
#  '143': 613,
#  '1454': 614,
#  '146': 615,
#  '147': 616,
#  '1473.': 617,
#  '14a': 618,
#  '14th': 619,
#  '15': 620,
#  '15+': 621,
#  '15,000.00': 622,
#  '15-16': 623,
#  '15-20': 624,
#  '15-30': 625,
#  '15-minute': 626,
#  '15-year': 627,
#  '15-year-old': 628,
#  '15.': 629,
#  '15.99': 630,
#  '15/16': 631,
#  '15/16-years-old': 632,
#  '150': 633,
#  '1500': 634,
#  '1500.00': 635,
#  '15000': 636,
#  '1500b': 637,
#  '1500s': 638,
#  '150th': 639,
#  '151': 640,
#  '152,000,000': 641,
#  '153': 642,
#  '1588': 643,
#  '1594': 644,
#  '15ft': 645,
#  '15k': 646,
#  '15th': 647,
#  '15ã\x82': 648,
#  '16': 649,
#  '16-minute': 650,
#  '16-year': 651,
#  '16-year-old': 652,
#  '16-yr-old': 653,
#  '16.': 654,
#  '16/month': 655,
#  '160': 656,
#  '1600': 657,
#  '1600s': 658,
#  '162': 659,
#  '163-minute': 660,
#  '1690': 661,
#  '16:9': 662,
#  '16mm': 663,
#  '16th': 664,
#  '16th-century': 665,
#  '16ã\x83â¨me': 666,
#  '17': 667,
#  '17-year': 668,
#  '17-year-old': 669,
#  '170': 670,
#  '1700': 671,
#  '175': 672,
#  '1759.': 673,
#  '177': 674,
#  '1780s': 675,
#  '1790': 676,
#  '1792': 677,
#  '1794': 678,
#  '1798': 679,
#  '17th': 680,
#  '17th-century': 681,
#  '18': 682,
#  '18+': 683,
#  '18,000': 684,
#  '18,000+': 685,
#  '18-24': 686,
#  '18-29': 687,
#  '18-49': 688,
#  '18-year-old': 689,
#  '18.': 690,
#  '18.th-century': 691,
#  '18/6/02': 692,
#  '180': 693,
#  '1800': 694,
#  '1800s': 695,
#  '180s': 696,
#  '1816': 697,
#  '1823.': 698,
#  '1824': 699,
#  '1830': 700,
#  '1832': 701,
#  '1837.': 702,
#  '1840': 703,
#  '1846': 704,
#  '1847': 705,
#  '1847.': 706,
#  '1850': 707,
#  '1850s': 708,
#  '1852-1913': 709,
#  '1853': 710,
#  '1853.': 711,
#  '1860s': 712,
#  '1861': 713,
#  '1863': 714,
#  '1863-1901': 715,
#  '1865': 716,
#  '1866': 717,
#  '1870': 718,
#  '1870s': 719,
#  '1871': 720,
#  '1873': 721,
#  '1876': 722,
#  '1876.': 723,
#  '1886': 724,
#  '1888': 725,
#  '188o': 726,
#  '1890': 727,
#  '1890.': 728,
#  '1890s': 729,
#  '1890s.': 730,
#  '1891': 731,
#  '1891-1953': 732,
#  '1892': 733,
#  '1896-1899': 734,
#  '1898': 735,
#  '1898.': 736,
#  '1899': 737,
#  '18:32': 738,
#  '18th': 739,
#  '18year': 740,
#  '19': 741,
#  '19,863,221': 742,
#  '19-21': 743,
#  '19-year-old': 744,
#  '19.': 745,
#  '19.99': 746,
#  '1900': 747,
#  '1902': 748,
#  '1904': 749,
#  '1905': 750,
#  '1906': 751,
#  '1908': 752,
#  '1909': 753,
#  '1910': 754,
#  '1912': 755,
#  '1913': 756,
#  '1913.': 757,
#  '1914': 758,
#  '1914-': 759,
#  '1915': 760,
#  '1916': 761,
#  '1917': 762,
#  '1917.': 763,
#  '1918': 764,
#  '1918-20': 765,
#  '1918.': 766,
#  '1918.it': 767,
#  '1919': 768,
#  '192': 769,
#  '1920': 770,
#  '1920-1939': 771,
#  '1920s': 772,
#  '1920s-spring': 773,
#  '1920s.': 774,
#  '1921': 775,
#  '1921.': 776,
#  '1922': 777,
#  '1922.': 778,
#  '1923': 779,
#  '1924': 780,
#  '1924/1940': 781,
#  '1925': 782,
#  '1925.': 783,
#  '1926': 784,
#  '1927': 785,
#  '1927-1928': 786,
#  '1927.': 787,
#  '1928': 788,
#  '1928-1929': 789,
#  '1928.': 790,
#  '1929': 791,
#  '1930': 792,
#  "1930's-like": 793,
#  '1930.': 794,
#  '1930s': 795,
#  '1930s-50s': 796,
#  '1930s.': 797,
#  '1930s/40s': 798,
#  '1931': 799,
#  '1931-39': 800,
#  '1931.': 801,
#  '1932': 802,
#  '1933': 803,
#  '1933.': 804,
#  '1933/2005': 805,
#  '1934': 806,
#  '1934-1938': 807,
#  '1934.': 808,
#  '1935': 809,
#  '1935.': 810,
#  '1936': 811,
#  '1936-1939': 812,
#  '1936-59': 813,
#  '1936.': 814,
#  '1937': 815,
#  '1937.': 816,
#  '1938': 817,
#  '1938-1981': 818,
#  '1938.': 819,
#  '1939': 820,
#  '1939.': 821,
#  '1939.in': 822,
#  '1939.it': 823,
#  '1939/40': 824,
#  '193o': 825,
#  '1940': 826,
#  "1940's.": 827,
#  '1940.': 828,
#  '1940s': 829,
#  '1940s.': 830,
#  '1940s/50s': 831,
#  '1941': 832,
#  "1941-'45.": 833,
#  '1942': 834,
#  '1942.': 835,
#  '1943': 836,
#  '1943.': 837,
#  '1944': 838,
#  '1944.': 839,
#  '1945': 840,
#  '1945-2000.': 841,
#  '1945.': 842,
#  '1946': 843,
#  '1947': 844,
#  '1947.': 845,
#  '1948': 846,
#  '1948.': 847,
#  '1949': 848,
#  '1949-51': 849,
#  '1949.': 850,
#  '1950': 851,
#  "1950's.": 852,
#  '1950.': 853,
#  '1950s': 854,
#  '1950s-styled': 855,
#  '1950s.': 856,
#  '1951': 857,
#  '1951.': 858,
#  '1952': 859,
#  '1952/53': 860,
#  '1953': 861,
#  '1953.': 862,
#  '1954': 863,
#  '1954-': 864,
#  '1954.': 865,
#  '1955': 866,
#  '1955,1956,1957': 867,
#  '1955-': 868,
#  '1955-1965': 869,
#  '1955.': 870,
#  '1956': 871,
#  '1957': 872,
#  '1957-1965': 873,
#  '1958': 874,
#  '1958.': 875,
#  '1959': 876,
#  '1959.': 877,
#  '196': 878,
#  '1960': 879,
#  "1960's.": 880,
#  "1960's/1970": 881,
#  '1960.': 882,
#  '1960s': 883,
#  '1960s.': 884,
#  '1961': 885,
#  '1961-': 886,
#  '1961.': 887,
#  '1961s': 888,
#  '1962': 889,
#  '1963': 890,
#  '1963.': 891,
#  '1964': 892,
#  '1964.': 893,
#  '1964.the': 894,
#  '1965': 895,
#  '1965.': 896,
#  '1966': 897,
#  '1967': 898,
#  '1967.': 899,
#  '1968': 900,
#  '1968-1970': 901,
#  '1968.': 902,
#  '1969': 903,
#  '1969-': 904,
#  '1969-74.': 905,
#  '1969.': 906,
#  '1970': 907,
#  "1970's-80": 908,
#  "1970's/80": 909,
#  '1970.': 910,
#  '1970ish': 911,
#  '1970s': 912,
#  '1970s-style': 913,
#  '1970s.': 914,
#  '1971': 915,
#  '1971.': 916,
#  '1972': 917,
#  '1972-': 918,
#  '1972.': 919,
#  '1973': 920,
#  '1973-1974': 921,
#  '1973-76.': 922,
#  '1973.': 923,
#  '1974': 924,
#  '1974-1980': 925,
#  '1974.': 926,
#  '1975': 927,
#  '1975-': 928,
#  '1975.': 929,
#  '1976': 930,
#  '1976-1984': 931,
#  '1976.': 932,
#  '1977': 933,
#  '1977-1979': 934,
#  '1977.': 935,
#  '1978': 936,
#  '1978-1987': 937,
#  '1978.': 938,
#  '1978/1979': 939,
#  '1979': 940,
#  '1979-80': 941,
#  '1979.': 942,
#  '197o': 943,
#  '1980': 944,
#  "1980's.": 945,
#  '1980.': 946,
#  '1980ies': 947,
#  '1980s': 948,
#  '1980s.': 949,
#  '1981': 950,
#  '1981-82': 951,
#  '1981.': 952,
#  '1982': 953,
#  '1982.': 954,
#  '1982s': 955,
#  '1983': 956,
#  '1983-85': 957,
#  '1983.': 958,
#  '1983.i': 959,
#  '1983/4': 960,
#  '1984': 961,
#  '1984.': 962,
#  '1984ish': 963,
#  '1985': 964,
#  '1985.': 965,
#  '1986': 966,
#  '1986.': 967,
#  '1986.the': 968,
#  '1987': 969,
#  '1987.': 970,
#  '1987.i': 971,
#  '1988': 972,
#  '1988.': 973,
#  '1989': 974,
#  '1989.': 975,
#  '1990': 976,
#  '1990.': 977,
#  '1990s': 978,
#  '1990s.': 979,
#  '1991': 980,
#  '1991.': 981,
#  '1992': 982,
#  '1992.': 983,
#  '1993': 984,
#  '1993.': 985,
#  '1993/4': 986,
#  '1994': 987,
#  '1994.': 988,
#  '1995': 989,
#  '1995.': 990,
#  '1996': 991,
#  '1996.': 992,
#  '1997': 993,
#  '1997-98': 994,
#  '1997.': 995,
#  '1998': 996,
#  '1998-era': 997,
#  '1998.': 998,
#  '1998.about': 999,
#  ...}

# %%
def one_hot_vector(document, problem_vocabulary):
    vector = np.zeros(len(problem_vocabulary),dtype=int)
    for token in document.split():
        vector[problem_vocabulary[token]] = 1
    return vector
def one_hot_matriz(lista):
    matriz=[]
    for i in lista:
        matriz.append(one_hot_vector(i, problem_vocabulary))
    return matriz
        
matriz=one_hot_matriz(listaDeComentarios)

# %%
#matriz
#print(type(matriz)) #<class 'list'>

# matriz = np.array(matriz)

# print(type(matriz))
# matriz

matriz.shape '''68795 es el tamaño del vocabulario del problema'''
# Out:
# (10000, 68795)

# %%
print("Numero de comentarios utilizados: " ,len(data))
# Out:
# Numero de comentarios utilizados:  10000

# %%
matrizDic=[]
i=0
for index, row in data_prueba.iterrows():
    z = {'tokenizado':matriz[i],'clasificacion':row['Label']}
    i=i+1
    matrizDic.append(z)

# %%
#matrizDic
print(matrizDic[0])
print(matrizDic[1])
# Out:
# {'tokenizado': array([0, 0, 0, ..., 0, 0, 0]), 'clasificacion': 'neg'}
# {'tokenizado': array([0, 0, 0, ..., 0, 0, 0]), 'clasificacion': 'pos'}

# %%
listaParaEntrenar=[]
for i in matrizDic:
    if(i["clasificacion"]=="pos"):
        listaParaEntrenar.append([i["tokenizado"], 1])
    else:
        listaParaEntrenar.append([i["tokenizado"], 0])

# %%
# listaParaEntrenar
print(listaParaEntrenar[0])
print(listaParaEntrenar[1])
# Out:
# [array([0, 0, 0, ..., 0, 0, 0]), 0]
# [array([0, 0, 0, ..., 0, 0, 0]), 1]

# %%
df = pd.DataFrame(listaParaEntrenar)
dfExpandido = df[0].apply(pd.Series)
dfExpandido["res"]=df[1]
tamMat=len(problem_vocabulary)

# %%
X = dfExpandido.iloc[:, np.r_[0:tamMat]]
y = dfExpandido["res"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training, 30% test
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (7000, 69440) (3000, 69440) (7000,) (3000,)

# %%
treeV4=RandomForestClassifier(n_estimators=88)

# %%
treeV4.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=88,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
print('accuracy del clasificador - version 4 : {0:.2f}'.format(accuracy_score(y_test, treeV4.predict(X_test))))
# confusion matrix
print('matriz de confusión del clasificador - version 4: \n {0}'.format(confusion_matrix(y_test, treeV4.predict(X_test))))
# precision 
print('precision del clasificador - version 4 : {0:.2f}'.format(precision_score(y_test, treeV4.predict(X_test))))
# recall
print('recall del clasificador - version 4 : {0:.2f}'.format(recall_score(y_test, treeV4.predict(X_test))))
# f1
print('f1 del clasificador - version 4 : {0:.2f}'.format(f1_score(y_test, treeV4.predict(X_test))))
# Out:
# accuracy del clasificador - version 4 : 0.83
# matriz de confusión del clasificador - version 4:
#  [[1296  214]
#  [ 283 1207]]
# precision del clasificador - version 4 : 0.85
# recall del clasificador - version 4 : 0.81
# f1 del clasificador - version 4 : 0.83

# %%
ruta_archivo_clasificador = os.path.join("Clasificador", "tree_v4.pkl")
archivo_clasificador = open(ruta_archivo_clasificador, "wb")
pickle.dump(treeV4, archivo_clasificador)
archivo_clasificador.close()

# %%
ruta_archivo_vocabulario = os.path.join("Clasificador","VocabularioProblema.pkl")

#Abrir el archivo para escribir contenido binario
archivo_vocabulario = open(ruta_archivo_vocabulario, "wb")

pickle.dump(problem_vocabulary, archivo_vocabulario,protocol=2)

archivo_vocabulario.close()
